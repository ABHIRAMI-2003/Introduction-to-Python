# %% [markdown]
# <a href="https://colab.research.google.com/github/ABHIRAMI-2003/Introduction-to-Python/blob/main/seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
exercise=sns.load_dataset("exercise")

# %%
exercise.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
iris=sns.load_dataset("iris")

# %%
sns.barplot(x='species', y='sepal_length', data=iris)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.lineplot(x='species', y='sepal_length', data=iris)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.stripplot(x='species', y='petal_length', data=iris)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.pairplot(data=iris)

# %%
sns.jointplot(data=iris, x='petal_length' ,y='sepal_length')
